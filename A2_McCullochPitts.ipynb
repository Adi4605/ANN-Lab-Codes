# %%
import numpy as np

# %%
x = np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
w = np.array([1,-1])
theta = 1
# Out:
# A B Output

# %%
print("A B Output")
for i in x:
    s = np.dot(i,w)

    if s>= theta:
        y=1
    else:
        y=0

    print(i[0], i[1], " ", y)
# Out:
# A B Output
# 0 0   0
# 0 1   0
# 1 0   1
# 1 1   0
